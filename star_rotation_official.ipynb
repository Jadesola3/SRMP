# %% [markdown]
# <a href="https://colab.research.google.com/github/Jadesola3/SRMP/blob/main/star_rotation_official.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('./Gaia_Prot_cmatch.csv')
len(df)
# Out:
# 94064

# %%
import matplotlib.pyplot as plt

# %%
list(df.columns)
# Out:
# ['Prot',
#  'abs_G',
#  'teff_calc',
#  'source_id',
#  'solution_id',
#  'designation',
#  'random_index',
#  'ref_epoch',
#  'ra',
#  'ra_error',
#  'dec',
#  'dec_error',
#  'parallax',
#  'parallax_error',
#  'parallax_over_error',
#  'pm',
#  'pmra',
#  'pmra_error',
#  'pmdec',
#  'pmdec_error',
#  'ra_dec_corr',
#  'ra_parallax_corr',
#  'ra_pmra_corr',
#  'ra_pmdec_corr',
#  'dec_parallax_corr',
#  'dec_pmra_corr',
#  'dec_pmdec_corr',
#  'parallax_pmra_corr',
#  'parallax_pmdec_corr',
#  'pmra_pmdec_corr',
#  'astrometric_n_obs_al',
#  'astrometric_n_obs_ac',
#  'astrometric_n_good_obs_al',
#  'astrometric_n_bad_obs_al',
#  'astrometric_gof_al',
#  'astrometric_chi2_al',
#  'astrometric_excess_noise',
#  'astrometric_excess_noise_sig',
#  'astrometric_params_solved',
#  'astrometric_primary_flag',
#  'nu_eff_used_in_astrometry',
#  'pseudocolour',
#  'pseudocolour_error',
#  'ra_pseudocolour_corr',
#  'dec_pseudocolour_corr',
#  'parallax_pseudocolour_corr',
# ...

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Jadesola3/SRMP.git
# Out:
# Cloning into 'SRMP'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 49 (delta 20), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (49/49), 442.03 KiB | 12.63 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
plt.plot(df['Prot'], df['ra'], '.')
plt.xlabel('prot')
plt.ylabel('ra')
# Out:
# Text(0, 0.5, 'ra')

# %%
plt.plot(df['Prot'], df['ra'], '.')
plt.xlabel('prot')
plt.ylabel('ra')

# %%
plt.plot(df['Prot'], df['dec'], '.')
plt.xlabel('prot')
plt.ylabel('dec')
# Out:
# Text(0, 0.5, 'ra')

# %%
plt.plot(df['Prot'], df['pm'], '.')
plt.xlabel('prot')
plt.ylabel('pm')
# Out:
# Text(0, 0.5, 'ra')

# %%
plt.plot(df['Prot'], df['phot_bp_n_obs'], '.')
plt.xlabel('prot')
plt.ylabel('phot_bp_n_obs')
# Out:
# Text(0, 0.5, 'phot_bp_n_obs')

# %%
len(df)
# Out:
# 4532

# %%
plt.plot(df['Prot'], df['bp_g'], '.')
plt.xlabel('Prot')
plt.ylabel('bp_g')
# Out:
# Text(0, 0.5, 'bp_g')

# %%
plt.plot(df['Prot'], df['g_rp'], '.')
plt.xlabel('Prot')
plt.ylabel('g_rp')
# Out:
# Text(0, 0.5, 'g_rp')

# %%
plt.plot(df['Prot'], df['l'], '.')
plt.xlabel('Prot')
plt.ylabel('l')
# Out:
# Text(0, 0.5, 'l')

# %%
plt.plot(df['Prot'], df['b'], '.')
plt.xlabel('Prot')
plt.ylabel('b')
# Out:
# Text(0, 0.5, 'b')

# %%
plt.plot(df['Prot'], df['ruwe'], '.')
plt.xlabel('Prot')
plt.ylabel('ruwe')
# Out:
# Text(0, 0.5, 'ruwe')

# %%
plt.plot(df['Prot'], df['pmdec'], '.')
plt.xlabel('Prot')
plt.ylabel('pmdec')
# Out:
# Text(0, 0.5, 'pmdec')

# %% [markdown]
# plt.gca().invert_xaxis()
# plt.gca().invert_yaxis()
