# %% [markdown]
# <a href="https://colab.research.google.com/github/Jadesola3/SRMP/blob/main/star_rotation_official.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('./Gaia_Prot_cmatch.csv')
len(df)
# Out:
# 94064

# %%
import matplotlib.pyplot as plt

# %%
list(df.columns)
# Out:
# ['Prot',
#  'abs_G',
#  'teff_calc',
#  'source_id',
#  'solution_id',
#  'designation',
#  'random_index',
#  'ref_epoch',
#  'ra',
#  'ra_error',
#  'dec',
#  'dec_error',
#  'parallax',
#  'parallax_error',
#  'parallax_over_error',
#  'pm',
#  'pmra',
#  'pmra_error',
#  'pmdec',
#  'pmdec_error',
#  'ra_dec_corr',
#  'ra_parallax_corr',
#  'ra_pmra_corr',
#  'ra_pmdec_corr',
#  'dec_parallax_corr',
#  'dec_pmra_corr',
#  'dec_pmdec_corr',
#  'parallax_pmra_corr',
#  'parallax_pmdec_corr',
#  'pmra_pmdec_corr',
#  'astrometric_n_obs_al',
#  'astrometric_n_obs_ac',
#  'astrometric_n_good_obs_al',
#  'astrometric_n_bad_obs_al',
#  'astrometric_gof_al',
#  'astrometric_chi2_al',
#  'astrometric_excess_noise',
#  'astrometric_excess_noise_sig',
#  'astrometric_params_solved',
#  'astrometric_primary_flag',
#  'nu_eff_used_in_astrometry',
#  'pseudocolour',
#  'pseudocolour_error',
#  'ra_pseudocolour_corr',
#  'dec_pseudocolour_corr',
#  'parallax_pseudocolour_corr',
# ...

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Jadesola3/SRMP.git
# Out:
# Cloning into 'SRMP'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 55 (delta 23), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (55/55), 1.89 MiB | 5.96 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
plt.plot(df['Prot'], df['ra'], '.')
plt.xlabel('prot')
plt.ylabel('ra')
# Out:
# Text(0, 0.5, 'ra')

# %%
plt.plot(df['Prot'], df['ra'], '.')
plt.xlabel('prot')
plt.ylabel('ra')
# Out:
# Text(0, 0.5, 'ra')

# %%
plt.plot(df['Prot'], df['dec'], '.')
plt.xlabel('prot')
plt.ylabel('dec')
# Out:
# Text(0, 0.5, 'dec')

# %%
plt.plot(df['Prot'], df['pm'], '.')
plt.xlabel('prot')
plt.ylabel('pm')
# Out:
# Text(0, 0.5, 'pm')

# %%
plt.plot(df['Prot'], df['phot_bp_n_obs'], '.')
plt.xlabel('prot')
plt.ylabel('phot_bp_n_obs')
# Out:
# Text(0, 0.5, 'phot_bp_n_obs')

# %%
len(df)
# Out:
# 10196

# %%
plt.plot(df['Prot'], df['bp_g'], '.')
plt.xlabel('Prot')
plt.ylabel('bp_g')
# Out:
# Text(0, 0.5, 'bp_g')

# %%
plt.plot(df['Prot'], df['g_rp'], '.')
plt.xlabel('Prot')
plt.ylabel('g_rp')
# Out:
# Text(0, 0.5, 'g_rp')

# %%
plt.plot(df['Prot'], df['l'], '.')
plt.xlabel('Prot')
plt.ylabel('l')
# Out:
# Text(0, 0.5, 'l')

# %%
plt.plot(df['Prot'], df['b'], '.')
plt.xlabel('Prot')
plt.ylabel('b')
# Out:
# Text(0, 0.5, 'b')

# %%
plt.plot(df['Prot'], df['ruwe'], '.')
plt.xlabel('Prot')
plt.ylabel('ruwe')
# Out:
# Text(0, 0.5, 'ruwe')

# %%
plt.plot(df['Prot'], df['pmdec'], '.')
plt.xlabel('Prot')
plt.ylabel('pmdec')
# Out:
# Text(0, 0.5, 'pmdec')

# %%
plt.plot(df['Prot'], df['phot_g_n_obs'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_g_n_obs')
# Out:
# Text(0, 0.5, 'phot_g_n_obs')

# %%
plt.plot(df['Prot'], df['phot_g_mean_flux'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_g_mean_flux')
# Out:
# Text(0, 0.5, 'phot_g_mean_flux')

# %%
plt.plot(df['Prot'], df['phot_g_mean_flux_error'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_g_mean_flux_error')
# Out:
# Text(0, 0.5, 'phot_g_mean_flux_error')

# %%
plt.plot(df['Prot'], df['phot_g_mean_flux_over_error'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_g_mean_flux_over_error')
# Out:
# Text(0, 0.5, 'phot_g_mean_flux_over_error')

# %%
plt.plot(df['phot_g_mean_mag'], df['Prot'], '.')
plt.xlabel('hot_g_mean_mag')
plt.ylabel('Prot')
# Out:
# Text(0, 0.5, 'Prot')

# %%
plt.plot(df['Prot'], df['visibility_periods_used'], '.')
plt.xlabel('Prot')
plt.ylabel('visibility_periods_used')
# Out:
# Text(0, 0.5, 'visibility_periods_used')

# %%
plt.plot(df['Prot'], df['astrometric_sigma5d_max'], '.')
plt.xlabel('Prot')
plt.ylabel('astrometric_sigma5d_max')
# Out:
# Text(0, 0.5, 'astrometric_sigma5d_max')

# %%
plt.plot(df['Prot'], df['matched_transits'], '.')
plt.xlabel('Prot')
plt.ylabel('matched_transits')
# Out:
# Text(0, 0.5, 'matched_transits')

# %%
plt.plot(df['Prot'], df['new_matched_transits'], '.')
plt.xlabel('Prot')
plt.ylabel('new_matched_transits')
# Out:
# Text(0, 0.5, 'new_matched_transits')

# %%
plt.plot(df['Prot'], df['scan_direction_strength_k1'], '.')
plt.xlabel('Prot')
plt.ylabel('scan_direction_strength_k1')
# Out:
# Text(0, 0.5, 'scan_direction_strength_k1')

# %%
plt.plot(df['Prot'], df['scan_direction_strength_k2'], '.')
plt.xlabel('Prot')
plt.ylabel('scan_direction_strength_k2')
# Out:
# Text(0, 0.5, 'scan_direction_strength_k2')

# %%
plt.plot(df['Prot'], df['scan_direction_strength_k3'], '.')
plt.xlabel('Prot')
plt.ylabel('scan_direction_strength_k3')
# Out:
# Text(0, 0.5, 'scan_direction_strength_k3')

# %%
plt.plot(df['Prot'], df['scan_direction_strength_k4'], '.')
plt.xlabel('Prot')
plt.ylabel('scan_direction_strength_k4')
# Out:
# Text(0, 0.5, 'scan_direction_strength_k4')

# %%
plt.plot(df['Prot'], df['parallax'], '.')
plt.xlabel('Prot')
plt.ylabel('parallax')
# Out:
# Text(0, 0.5, 'parallax')

# %%
plt.plot(df['Prot'], df['parallax_error'], '.')
plt.xlabel('Prot')
plt.ylabel('parallax_error')
# Out:
# Text(0, 0.5, 'parallax_error')

# %%
plt.plot(df['Prot'], df['parallax_over_error'], '.')
plt.xlabel('Prot')
plt.ylabel('parallax_over_error')
# Out:
# Text(0, 0.5, 'parallax_over_error')

# %%
plt.plot(df['Prot'], df['source_id'], '.')
plt.xlabel('Prot')
plt.ylabel('source_id')
# Out:
# Text(0, 0.5, 'source_id')

# %%
plt.plot(df['Prot'], df['solution_id'], '.')
plt.xlabel('Prot')
plt.ylabel('solution_id')
# Out:
# Text(0, 0.5, 'solution_id')

# %%
plt.plot(df['Prot'], df['designation'], '.')
plt.xlabel('Prot')
plt.ylabel('designation')
# Out:
# Text(0, 0.5, 'designation')

# %%
plt.plot(df['Prot'], df['random_index'], '.')
plt.xlabel('Prot')
plt.ylabel('random_index')
# Out:
# Text(0, 0.5, 'random_index')

# %%
plt.plot(df['Prot'], df['astrometric_params_solved'], '.')
plt.xlabel('Prot')
plt.ylabel('astrometric_params_solved')
# Out:
# Text(0, 0.5, 'astrometric_params_solved')

# %%
plt.plot(df['Prot'], df['astrometric_primary_flag'], '.')
plt.xlabel('Prot')
plt.ylabel('astrometric_primary_flag')
# Out:
# Text(0, 0.5, 'astrometric_primary_flag')

# %%
plt.plot(df['Prot'], df['nu_eff_used_in_astrometry'], '.')
plt.xlabel('Prot')
plt.ylabel('nu_eff_used_in_astrometry')
# Out:
# Text(0, 0.5, 'nu_eff_used_in_astrometry')

# %%
plt.plot(df['Prot'], df['pseudocolour'], '.')
plt.xlabel('Prot')
plt.ylabel('pseudocolour')
# Out:
# Text(0, 0.5, 'pseudocolour')

# %%
plt.plot(df['Prot'], df['pseudocolour_error'], '.')
plt.xlabel('Prot')
plt.ylabel('pseudocolour_error')
# Out:
# Text(0, 0.5, 'pseudocolour_error')

# %%
plt.plot(df['Prot'], df['ra_pseudocolour_corr'], '.')
plt.xlabel('Prot')
plt.ylabel('ra_pseudocolour_corr')
# Out:
# Text(0, 0.5, 'ra_pseudocolour_corr')

# %%
plt.plot(df['Prot'], df['pmdec_pseudocolour_corr'], '.')
plt.xlabel('Prot')
plt.ylabel('pmdec_pseudocolour_corr')
# Out:
# Text(0, 0.5, 'pmdec_pseudocolour_corr')

# %%
plt.plot(df['Prot'], df['dec_pseudocolour_corr'], '.')
plt.xlabel('Prot')
plt.ylabel('dec_pseudocolour_corr')
# Out:
# Text(0, 0.5, 'dec_pseudocolour_corr')

# %%
plt.plot(df['Prot'], df['parallax_pseudocolour_corr'], '.')
plt.xlabel('Prot')
plt.ylabel('parallax_pseudocolour_corr')
# Out:
# Text(0, 0.5, 'parallax_pseudocolour_corr')

# %%
plt.plot(df['Prot'], df['pmra_pseudocolour_corr'], '.')
plt.xlabel('Prot')
plt.ylabel('pmra_pseudocolour_corr')
# Out:
# Text(0, 0.5, 'pmra_pseudocolour_corr')

# %%
plt.plot(df['Prot'], df['astrometric_matched_transits'], '.')
plt.xlabel('Prot')
plt.ylabel('astrometric_matched_transits')
# Out:
# Text(0, 0.5, 'astrometric_matched_transits')

# %%
plt.plot(df['Prot'], df['astrometric_primary_flag'], '.')
plt.xlabel('Prot')
plt.ylabel('astrometric_primary_flag')
# Out:
# Text(0, 0.5, 'astrometric_primary_flag')

# %%
plt.plot(df['Prot'], df['nu_eff_used_in_astrometry'], '.')
plt.xlabel('Prot')
plt.ylabel('nu_eff_used_in_astrometry')
# Out:
# Text(0, 0.5, 'nu_eff_used_in_astrometry')

# %%
plt.plot(df['Prot'], df['pseudocolour'], '.')
plt.xlabel('Prot')
plt.ylabel('pseudocolour')
# Out:
# Text(0, 0.5, 'pseudocolour')

# %%
plt.plot(df['Prot'], df['pseudocolour_error'], '.')
plt.xlabel('Prot')
plt.ylabel('pseudocolour_error')
# Out:
# Text(0, 0.5, 'pseudocolour_error')

# %%
plt.plot(df['Prot'], df['dr2_radial_velocity'], '.')
plt.xlabel('Prot')
plt.ylabel('dr2_radial_velocity')
# Out:
# Text(0, 0.5, 'dr2_radial_velocity')

# %%
plt.plot(df['Prot'], df['dr2_radial_velocity_error'], '.')
plt.xlabel('Prot')
plt.ylabel('dr2_radial_velocity_error')
# Out:
# Text(0, 0.5, 'dr2_radial_velocity_error')

# %%
plt.plot(df['Prot'], df['dr2_rv_nb_transits'], '.')
plt.xlabel('Prot')
plt.ylabel('dr2_rv_nb_transits')

# %%
plt.plot(df['Prot'], df['dr2_rv_template_teff'], '.')
plt.xlabel('Prot')
plt.ylabel('dr2_rv_template_teff')
# Out:
# Text(0, 0.5, 'dr2_rv_template_teff')

# %%
plt.plot(df['Prot'], df['dr2_rv_template_logg'], '.')
plt.xlabel('Prot')
plt.ylabel('dr2_rv_template_logg')
# Out:
# Text(0, 0.5, 'dr2_rv_template_logg')

# %%
plt.plot(df['Prot'], df['dr2_rv_template_fe_h'], '.')
plt.xlabel('Prot')
plt.ylabel('dr2_rv_template_fe_h')
# Out:
# Text(0, 0.5, 'dr2_rv_template_fe_h')

# %%
plt.plot(df['Prot'], df['ecl_lon'], '.')
plt.xlabel('Prot')
plt.ylabel('ecl_lon')
# Out:
# Text(0, 0.5, 'ecl_lon')

# %%
plt.plot(df['Prot'], df['ecl_lat'], '.')
plt.xlabel('Prot')
plt.ylabel('ecl_lat')
# Out:
# Text(0, 0.5, 'ecl_lat')

# %%
plt.plot(df['Prot'], df['tab_uploaded_oid'], '.')
plt.xlabel('Prot')
plt.ylabel('tab_uploaded_oid')
# Out:
# Text(0, 0.5, 'tab_uploaded_oid')

# %%
plt.plot(df['Prot'], df['phot_bp_mean_flux_error'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_bp_mean_flux_error')
# Out:
# Text(0, 0.5, 'phot_bp_mean_flux_error')

# %%
plt.plot(df['Prot'], df['phot_bp_mean_flux_over_error'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_bp_mean_flux_over_error')
# Out:
# Text(0, 0.5, 'phot_bp_mean_flux_over_error')

# %%
plt.plot(df['Prot'], df['phot_bp_mean_mag'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_bp_mean_mag')
# Out:
# Text(0, 0.5, 'phot_bp_mean_mag')

# %%
plt.plot(df['Prot'], df['phot_rp_n_obs'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_rp_n_obs')
# Out:
# Text(0, 0.5, 'phot_rp_n_obs')

# %%
plt.plot(df['Prot'], df['phot_rp_mean_flux'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_rp_mean_flux')
# Out:
# Text(0, 0.5, 'phot_rp_mean_flux')

# %%
plt.plot(df['Prot'], df['phot_rp_mean_flux_error'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_rp_mean_flux_error')
# Out:
# Text(0, 0.5, 'phot_rp_mean_flux_error')

# %%
plt.plot(df['Prot'], df['phot_rp_mean_flux_over_error'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_rp_mean_flux_over_error')
# Out:
# Text(0, 0.5, 'phot_rp_mean_flux_over_error')

# %%
plt.plot(df['Prot'], df['phot_rp_mean_mag'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_rp_mean_mag')
# Out:
# Text(0, 0.5, 'phot_rp_mean_mag')

# %%
plt.plot(df['Prot'], df['phot_bp_n_contaminated_transits'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_bp_n_contaminated_transits')
# Out:
# Text(0, 0.5, 'phot_bp_n_contaminated_transits')

# %%
plt.plot(df['Prot'], df['phot_bp_n_blended_transits'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_bp_n_blended_transits')
# Out:
# Text(0, 0.5, 'phot_bp_n_blended_transits')

# %%
plt.plot(df['Prot'], df['phot_rp_n_contaminated_transits'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_rp_n_contaminated_transits')
# Out:
# Text(0, 0.5, 'phot_rp_n_contaminated_transits')

# %%
plt.plot(df['Prot'], df['phot_rp_n_blended_transits'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_rp_n_blended_transits')
# Out:
# Text(0, 0.5, 'phot_rp_n_blended_transits')

# %%
plt.plot(df['Prot'], df['phot_proc_mode'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_proc_mode')
# Out:
# Text(0, 0.5, 'phot_proc_mode')

# %%
plt.plot(df['Prot'], df['phot_bp_rp_excess_factor'], '.')
plt.xlabel('Prot')
plt.ylabel('phot_bp_rp_excess_factor')
# Out:
# Text(0, 0.5, 'phot_bp_rp_excess_factor')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %%
plt.plot(df['Prot'], df[''], '.')
plt.xlabel('Prot')
plt.ylabel('')

# %% [markdown]
# plt.gca().invert_xaxis()
# plt.gca().invert_yaxis()
